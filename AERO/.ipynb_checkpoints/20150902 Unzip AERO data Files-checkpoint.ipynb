# %%
import os

# %%
filenames = filter(lambda x: "Engine" in x,os.listdir("/storage3/w/richard/Fall2015/aero/"))

# %%
## write script to unzip the file into folder with their name
script = ""
for filename in filenames:
#     script += 'mkdir {}\n'.format(filename[:-4])
#     script += 'unzip {} -d {}\n'.format(filename, filename[:-4])
print script
with open("/storage3/w/richard/Fall2015/aero/unzipFiles.sh","w") as f: f.write(script)
# Out:
# unzip Engine0111.zip -d Engine0111
# unzip Engine0060.zip -d Engine0060
# unzip Engine0110.zip -d Engine0110
# unzip Engine0126.zip -d Engine0126
# unzip Engine0029.zip -d Engine0029
# unzip Engine0152.zip -d Engine0152
# unzip Engine0123.zip -d Engine0123
# unzip Engine0165.zip -d Engine0165
# unzip Engine0104.zip -d Engine0104
# unzip Engine0087.zip -d Engine0087
# unzip Engine0094.zip -d Engine0094
# unzip Engine0024.zip -d Engine0024
# unzip Engine0149.zip -d Engine0149
# unzip Engine0200.zip -d Engine0200
# unzip Engine0065.zip -d Engine0065
# unzip Engine0114.zip -d Engine0114
# unzip Engine0071.zip -d Engine0071
# unzip Engine0084.zip -d Engine0084
# unzip Engine0088.zip -d Engine0088
# unzip Engine0090.zip -d Engine0090
# unzip Engine0103.zip -d Engine0103
# unzip Engine0011.zip -d Engine0011
# unzip Engine0018.zip -d Engine0018
# unzip Engine0043.zip -d Engine0043
# unzip Engine0153.zip -d Engine0153
# unzip Engine0102.zip -d Engine0102
# unzip Engine0159.zip -d Engine0159
# ...
